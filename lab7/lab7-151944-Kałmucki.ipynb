# %% [markdown]
# # Intro to ML

# %% [markdown]
# This assignment departs from the tradition of implementing everything from scratch and we will use a few libraries. First: `numpy`, the Python library for handling matrices.

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (1.23.5)

# %% [markdown]
# Next, `seaborn`, a library for easily plotting cute charts.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %% [markdown]
# Finally, `scikit-learn`, a library implementing many ML algorithm

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kalmu\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.23.5)

# %% [markdown]
# Thorought the whole assignment you can - if you want - use the `numpy` library.

# %%
import numpy as np

# %% [markdown]
# We begin by defining a simple dataset, mapping flat areas in `areas` to their rental prices (in Arbitrary Units of Currency, AUC for short) in `prices`. Both lists are of the same length, and are in the same order, i.e., the `i`-th flat has the area `areas[i]` and can be rented for `prices[i]` AUC

# %%
areas = [77.0, 50.0, 44.0, 65.0, 65.0, 52.0, 48.0, 45.0, 45.0, 36.0, 53.0, 43.0, 53.0, 27.0, 100.0, 52.0, 84.0, 77.0, 42.0, 75.0, 47.0, 52.0, 64.0, 42.0, 85.0, 30.0]
prices = [282, 250, 262, 399, 285, 308, 336, 277, 275, 219, 332, 262, 334, 185, 370, 329, 179, 265, 237, 330, 265, 345, 307, 270, 355, 179]

# %% [markdown]
# ## Task 1: prediction in 1D linear regression

# %% [markdown]
# Complete the following `predict` function so that, given a list of features and the weights in linear regression. Assume that `w1` represents the slope, whereas `w0` is the intercept. `x` is a single-dimensional vector (e.g., a `list` of `float`s) such that every value corresponds to the single feature of another example. `predict` should return a vector of the same length `y`, such that $y_i = w_1x_i + w_0$
#
# You can use the `numpy` library if it is convenient for you, but it is by no means necessary.

# %%
def predict(x, w1, w0):
    return w1*np.array(x) + w0

# %% [markdown]
# Let's test it!

# %%
feature = [1, 2, 3]
expected = [10, 20, 30]
predicted = predict(feature, 10, 0)

assert (np.array(predicted) == np.array(expected)).all()

# %%
feature = [1, 2, 3]
expected = [11, 12, 13]
predicted = predict(np.array(feature), 1, 10)

assert (np.array(predicted) == np.array(expected)).all()

# %% [markdown]
# ## Task 2: training a 1D linear regression model

# %% [markdown]
# Complete the following cell of code so it iteratively improves the weights of the model to find the best line mapping `x` to `y`. Use the gradient descent algorithm presented during the lecture. Again, `x` and `y` are vectors, such that `x[i]` is the feature of the `i`-th example, whereas `y[i]` is the decision attribute (i.e., the value to approximate with the line). `w1` and `w0` given as the parameters are the initial values for the parameters of the model (i.e., the line), whereas `max_iters` is the learning rate (denoted by $\eta$ in the slides). Finally, `learning_rate` is the number of steps (weight updates) to do. `train_linear_regression` should return a pair of values `(w1, w0)` representing the best line approximating `y` given `x` according to the mean squared error.
#
# Implement it on your own instead of using an implementation available in a library (e.g., `sklearn.linear_model.SGDRegressor`). You can, however, use `numpy` if it is convenient for you.

# %% [markdown]
# whereas `max_iters` is the learning rate - probably wasn't meant this way

# %%
#(⬇️) I increased learning rate and max iterations to make it be able to solve tasks below
def train_linear_regression(x, y, w1=0.0, w0=0.0, learning_rate=0.001, max_iters=100000):
    m = len(x)
    for _ in range(max_iters):
        w0, w1 = w0 - learning_rate * sum(w1*np.array(x) + w0 - np.array(y))/m, w1 - learning_rate * sum((w1*np.array(x) + w0 - np.array(y))*np.array(x))/m
    return (w1, w0)

# %% [markdown]
# Lets see how it works for a very simple case. The following cell should not fail.

# %%
x = [1, 2, 3]
y = [16, 26, 36]
w1, w0 = train_linear_regression(x, y)
print(f"Model: y={w1}x+{w0}")
assert abs(w1 - 10) <= 0.01
assert abs(w0 - 6) <= 0.01
# Out:
# Model: y=10.000003552471926x+5.999991924396326

# %% [markdown]
# Let's train a model for the data on the rental prices (you may need to tweak `learning_rate` and/or `max_iters`):

# %%
w1, w0 = train_linear_regression(areas, prices, learning_rate=0.0001, max_iters=100000)
print(f"Model: price = {w1} * area + {w0}")
# Out:
# Model: price = 2.820877963228235 * area + 120.98628676214642

# %% [markdown]
# And now let's see how the predictions and reality differ. Since comparing a bunch of numbers is inconvenient, we will plot a chart instead using the `seaborn` library. In the chart, the points represent the actual data, whereas the line is the output of the linear regression.

# %%
predicted_prices = predict(areas, w1, w0)

# %%
import seaborn as sns
sns.relplot(x=areas, y=prices)
sns.lineplot(x=areas, y=predicted_prices)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Task 3: mean-squared error

# %% [markdown]
# Comparing expected and predicted values on charts is not a very objective measure. Instead, it would be better to automate it. Complete the following function `mse` such that given two vectors `y_true` and `y_pred` of the same length, it returns the mean squared error, i.e., $$\frac{1}{n}\sum_{i=1}^n (y_i - \hat{y_i})^2$$ where $y$ stands for `y_true` and $\hat{y}$ for `y_pred`

# %%
def mse(y_true, y_pred) -> float:
    return np.sum((np.array(y_true)-np.array(y_pred))**2)/len(y_true)

# %% [markdown]
# Let's make sure it works

# %%
assert mse([1, 2, 3], [2, 5, 7]) == ((1-2)**2 + (2-5)**2 + (3-7)**2)/3

# %% [markdown]
# ## Interlude: ridge regression in scikit-learn

# %% [markdown]
# We will now use a slightly larger dataset called *diabetes*. We begin by loading it using a loader provied in the `scikit-learn` library

# %%
import sklearn.datasets
dataset = sklearn.datasets.load_diabetes()
print(dataset.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# Threre are 442 examples described by 10 features each, organized into a matrix `dataset.data`:

# %%
dataset.data.shape
# Out:
# (442, 10)

# %% [markdown]
# There is also a vector of values to predict:

# %%
dataset.target.shape
# Out:
# (442,)

# %%
print(f"The first example")
print("x[0]", dataset.data[0])
print("y[0]", dataset.target[0])
# Out:
# The first example
# x[0] [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]
# y[0] 151.0

# %% [markdown]
# We need to split the dataset into three parts:
# * a training set - to optimize the parameters of a model (e.g., the weights in the linear regression)
# * a validation (development) set - to optimize the hyperparameters of a model (e.g., the coefficient $\alpha$ in the ridge regression)
# * a test set - to see how well a model behaves on unseen data

# %%
import sklearn.model_selection
X, test_X, y, test_y = sklearn.model_selection.train_test_split(dataset.data, dataset.target, random_state=42, test_size=.2)
train_X, val_X, train_y, val_y = sklearn.model_selection.train_test_split(X, y, random_state=43, test_size=.125)
print("Training set (70% of 442):", train_X.shape, train_y.shape)
print("Validation set (10% of 442):", val_X.shape, val_y.shape)
print("Test set (20% of 442):", test_X.shape, test_y.shape)
# Out:
# Training set (70% of 442): (308, 10) (308,)
# Validation set (10% of 442): (45, 10) (45,)
# Test set (20% of 442): (89, 10) (89,)

# %% [markdown]
# Let's train a ridge regression model, i.e, a linear regression model with a regularization component to avoid overfitting.

# %%
from sklearn.linear_model import Ridge
regressor = Ridge()
regressor.fit(train_X, train_y)
# Out:
# Ridge()

# %% [markdown]
# How well the model fares in terms of MSE on the training set?

# %%
pred = regressor.predict(train_X)
mse(train_y, pred)
# Out:
# 3459.8762718175135

# %% [markdown]
# And on the validation set?

# %%
pred = regressor.predict(val_X)
mse(val_y, pred)
# Out:
# 3121.330659615392

# %% [markdown]
# Now let's see what happens if we use a different value of the hyperparameter $\alpha$

# %%
regressor = Ridge(alpha=10)
regressor.fit(train_X, train_y)
print("MSE on training:", mse(train_y, regressor.predict(train_X)))
print("MSE on validation:", mse(val_y, regressor.predict(val_X)))
# Out:
# MSE on training: 5304.004155582988
# MSE on validation: 4051.263093859394

# %% [markdown]
# ## Task 4: Hyperparameter optimization using the validation set

# %% [markdown]
# As you can see, the resulting values are very different. **Complete the function** below with some strategy to find the best value of the hyperparmeter `alpha` with respect to the mean-squared error `mse` on the validation set given as the parameters `val_X`, `val_y`. Use `train_X` and `train_y` as the training set. Return the best value of alpha. The strategy is up to you: you can use some set of fixed values, you can do something more elaborate. If you decide to use a fixed set of values, consider the cost function of the ridge regression and try to come up with a reasonable set of values (e.g., picking `[1, 1.1, 1.2]` is probably not that intersting)

# %%
#(⬇️) plot function of mse for different values of alpha to choose how to optimize it's value
def plot_alphas(train_X, train_y, val_X, val_y):
    out = []
    for x in np.arange(0,10,0.1):
        regressor = Ridge(alpha = x)
        regressor.fit(train_X, train_y)
        out.append(mse(val_y, regressor.predict(val_X)))
    sns.lineplot(x=np.arange(0,10,0.1), y=out)

# %%
plot_alphas(train_X, train_y, val_X, val_y)

# %% [markdown]
# As we can see on the graph of mse for given values of alpha, only optimum is for alpha somewhere between (0,1). Therefore local search should be a very nice algorithm for finding best value of alpha since it should always converge at global minimum.

# %%
#(⬇️) Local search checking mse for different values of alpha, starting with steps of 0.1 (for precision = 1) and making them smaller and smaller to match given precision
def alpha_optimization(train_X, train_y, val_X, val_y, precision = 10) -> float:
    assert precision <= 10
    a,n  = 0, 1
    for _ in range(precision):
        a, n = a*10, n*10
        prev = float('inf')
        while 1:
            regressor = Ridge(alpha = a/n)
            regressor.fit(train_X, train_y)
            err = mse(val_y, regressor.predict(val_X))
            if err>prev:
                a -= 1
                break
            else:
                prev = err
                a += 1
        while 1:
            regressor = Ridge(alpha = a/n)
            regressor.fit(train_X, train_y)
            err = mse(val_y, regressor.predict(val_X))
            if err>prev:
                a += 1
                break
            else:
                prev = err
                a -= 1
    return a/n

# %%
#(⬇️) I added new argument precision which specifies how many decimal points (max and default precision is 10) of alpha do we want
best_alpha = alpha_optimization(train_X, train_y, val_X, val_y)
print("The best alpha is", best_alpha)
# Out:
# The best alpha is 0.4643830781

# %% [markdown]
# ## Task 5: Using the test set

# %% [markdown]
# Finally, let's use the test set! We will train a regressor using the best alpha and then evaluate it on all three sets. However, before we do it, **write in the cell below your prediction**: will MSE on the test set be better or worse than on the validation set?

# %% [markdown]
# **I predict that: ...**

# %% [markdown]
# I wanted to say that I predict mean squared error for test set to be higher then for both training set and validation set since model attunes itself to perform as good as it can on those sets, however since in previous cells computed mse for validation set was lower then mse for training set I could see any result plausible

# %%
regressor = Ridge(alpha=best_alpha)
regressor.fit(train_X, train_y)
print("MSE on training:", mse(train_y, regressor.predict(train_X)))
print("MSE on validation:", mse(val_y, regressor.predict(val_X)))
print("MSE on test:", mse(test_y, regressor.predict(test_X)))
# Out:
# MSE on training: 3110.274695313953
# MSE on validation: 3055.95055791858
# MSE on test: 2938.193112398723

# %% [markdown]
# **Is the result consistent with your prediction, or did something surprise you? Comment on the result in the cell below.**

# %% [markdown]
# As I pointed out earlier I was expecting mse on test set to be higher then for training set, same as I was expecting mse on validation set to be higher then on training set. However I believe that due to small sample size of those sets results we get can differ a lot depending on what partitions we chose, so this result can be simple luck.

# %% [markdown]
# To further prove that in a cell below are results of evaluation of this model on different partitions of given set, as we can see mse of test set differs by a lot and a lot of them give larger error then for training set.

# %%
for r in range(0,100,10):
    X, test_X, y, test_y = sklearn.model_selection.train_test_split(dataset.data, dataset.target, random_state=r, test_size=.2)
    train_X, val_X, train_y, val_y = sklearn.model_selection.train_test_split(X, y, random_state=r, test_size=.125)
    regressor = Ridge(alpha=best_alpha)
    regressor.fit(train_X, train_y)
    print("MSE on training:", mse(train_y, regressor.predict(train_X)))
    print("MSE on validation:", mse(val_y, regressor.predict(val_X)))
    print("MSE on test:", mse(test_y, regressor.predict(test_X)))
    print()
# Out:
# MSE on training: 3036.620012460245
# MSE on validation: 2720.9564155717367
# MSE on test: 3294.064482389743
#
# MSE on training: 3110.935467469977
# MSE on validation: 3214.354301085018
# MSE on test: 3349.744701050967
#
# MSE on training: 3019.0481955690957
# MSE on validation: 2792.020364233876
# MSE on test: 3446.287596483155
#
# MSE on training: 3064.0555411006117
# MSE on validation: 3269.36045137596
# MSE on test: 3223.75412094638
#
# MSE on training: 2820.461076320609
# MSE on validation: 3118.294667099089
# MSE on test: 4017.9494949372493
#
# MSE on training: 3149.6414749055984
# MSE on validation: 3364.163720843538
# MSE on test: 2824.8145212422164
#
# MSE on training: 2967.0661032795074
# MSE on validation: 3475.728742819712
# MSE on test: 3628.127102378005
#
# MSE on training: 2995.6784326512748
# MSE on validation: 3020.9914351920243
# MSE on test: 3829.898211014218
#
# MSE on training: 3179.7400409145707
# MSE on validation: 2560.4154550916705
# MSE on test: 3102.5366639327067
#
# MSE on training: 3113.365626685018
# MSE on validation: 3455.951384115276
# MSE on test: 2950.712415889598
